# %%
from mip import *
import numpy as np
import json
import pandas as pd

# %%
constructors = json.load(open('./data/constructors.json'))
drivers = json.load(open('./data/drivers.json'))

# %%
BUDGET = 100
DRIVERS, TEAMS = 21, 10
DRIVERS_AMOUNT, TEAMS_AMOUNT = 5, 2

# %%
names = [d['driver'] for d in drivers]
team = [c['team'] for c in constructors]
new_budget = BUDGET

SEASON_POINTS = 0

for race in range(len(drivers[0]['races'])):
    driver_race_points = []
    team_race_points = []
    
    #  first race based on initial budget
    if race == 0:
        driver_price = [d['startPrice'] for d in drivers]
        team_price = [c['startPrice'] for c in constructors]
    # next races based on the maximal potential budget
    else:
        driver_price = [d['races'][race-1]['price'] for d in drivers]
        team_price = [c['races'][race-1]['price'] for c in constructors]
        
        # BUDGET = new_budget

    driver_race_points.append([d['races'][race]['points']['total'] for d in drivers])
    team_race_points.append([c['races'][race]['points']['total'] for c in constructors])

    # dataframes
    drivers_df = pd.DataFrame([names, driver_price, *driver_race_points], ['name', 'price', 'points']).T
    constructors_df = pd.DataFrame([team, team_price, *team_race_points], ['name', 'price', 'points']).T

    df = pd.concat([drivers_df, constructors_df], ignore_index=True)
    
    # define input data to linear programming
    ROW = df.shape[0]
    COL = df.shape[1]-1

    all_indexes = np.arange(0, ROW*COL, 1).reshape(ROW, COL)
    driver_indexes = np.arange(0, (ROW-TEAMS)*COL, 1).reshape(DRIVERS, COL)
    team_indexes = np.arange(DRIVERS*COL, ROW*COL, 1).reshape(TEAMS, COL)

    matrix = df.to_numpy()
    matrix = matrix[:, 1:].astype(float)
    data = np.array(matrix).flatten()

    # linear programming calculation
    m = Model(sense=MAXIMIZE, solver_name=CBC)

    y = [m.add_var(var_type=BINARY) for i in range(ROW)]
    # MINIMUM PRICE 
    m.objective = minimize(xsum(y[i] * data[all_indexes[i, 0]] for i in range(ROW)))
    # MAXIMUM POINTS 
    m.objective = maximize(xsum(y[i] * data[all_indexes[i, 1]] for i in range(ROW)))

    # NUMBER OF DRIVERS
    m += xsum(y[i] for i in range(DRIVERS)) == DRIVERS_AMOUNT
    # NUMBER OF TEAMS
    m += xsum(y[i] for i in range(DRIVERS, ROW)) == TEAMS_AMOUNT
    # BUDGET
    m += xsum(data[all_indexes[i, 0]]*y[i] for i in range(ROW)) <= new_budget

    m.optimize()
    squad = [i for i in range(ROW) if y[i].x >= 0.99]

    squad_data = df.iloc[squad]

    if race == 0:
        price_diff = driver_price = [d['races'][race]['price']-d['startPrice'] for d in drivers if d['driver'] in list(squad_data['name'])]
        price_diff = round(np.sum(price_diff), 2)
    else:
        price_diff = driver_price = [d['races'][race]['price']-d['races'][race-1]['price'] for d in drivers if d['driver'] in list(squad_data['name'])]
        price_diff = round(np.sum(price_diff), 2)

    # show info about price, points, best driver
    drivers_squad = squad_data.iloc[0:5]
    turbo_driver = drivers_squad[drivers_squad['points']== drivers_squad['points'].max()]

    print(f'Race: {drivers[0]["races"][race]["circuit"]}')
    print(f'Budget: {new_budget} mln')
    print('Squad')
    print(squad_data)
    print('')
    print(f'Turbo driver: {turbo_driver["name"].values[0]}')
    print(f'Price: {squad_data["price"].sum()}')
    print(f'Points (no boost): {squad_data["points"].sum()}')
    print(f'Points with turbo driver: {squad_data["points"].sum() + turbo_driver["points"].values[0]}')
    print('-----------------------------------------')
    
    SEASON_POINTS += squad_data["points"].sum() + turbo_driver["points"].values[0]

    if race == 0:
        price_diff = driver_price = [d['races'][race]['price']-d['startPrice'] for d in drivers if d['driver'] in list(squad_data['name'])]
        price_diff = round(np.sum(price_diff), 2)
    else:
        price_diff = driver_price = [d['races'][race]['price']-d['races'][race-1]['price'] for d in drivers if d['driver'] in list(squad_data['name'])]
        price_diff = round(np.sum(price_diff), 2)
        
    new_budget = new_budget + price_diff

print(f'Season points: {SEASON_POINTS}')
# Out:
# Race: Bahrain
# Budget: 100 mln
# Squad
#                name price points
# 0    Max Verstappen  26.9     35
# 1   Fernando Alonso   8.3     39
# 3       Zhou Guanyu   4.9     15
# 5      Sergio Perez    18     28
# 10     Lance Stroll   7.5     17
# 21         Red Bull  27.2     78
# 22     Aston Martin   6.7     52
#
# Turbo driver: Fernando Alonso
# Price: 99.5
# Points (no boost): 264
# Points with turbo driver: 303
# -----------------------------------------
# Race: Saudi Arabia
# Budget: 100.5 mln
# Squad
#                name price points
# 0    Max Verstappen    27     61
# 1   Fernando Alonso   8.5     23
# 3       Zhou Guanyu   4.9      6
# 15     Yuki Tsunoda   4.8      9
# 16    Nyck De Vries     5      7
# 21         Red Bull  27.3     95
# 23          Ferrari  22.1     59
#
# Turbo driver: Max Verstappen
# Price: 99.6
# Points (no boost): 260
# Points with turbo driver: 321
# -----------------------------------------
# Race: Australia
# Budget: 100.8 mln
# Squad
#                name price points
# 0    Max Verstappen  27.1     36
# 1   Fernando Alonso   8.7     23
# 3       Zhou Guanyu   4.9     15
# 5      Sergio Perez  18.2     52
# 10     Lance Stroll   7.5     21
# 21         Red Bull  27.4     98
# 22     Aston Martin   6.8     54
#
# Turbo driver: Sergio Perez
# Price: 100.59999999999998
# Points (no boost): 299
# Points with turbo driver: 351
# -----------------------------------------
# Race: Azerbaijan
# Budget: 101.3 mln
# Squad
#                name price points
# 1   Fernando Alonso   8.9     27
# 2   Charles Leclerc  21.1     29
# 5      Sergio Perez  18.3     61
# 7      Pierre Gasly   8.1     17
# 10     Lance Stroll   7.6     18
# 21         Red Bull  27.5    108
# 22     Aston Martin   6.9     55
#
# Turbo driver: Sergio Perez
# Price: 98.4
# Points (no boost): 315
# Points with turbo driver: 376
# -----------------------------------------
# Race: United States - Miami
# Budget: 101.8 mln
# Squad
#                name price points
# 0    Max Verstappen  27.3     64
# 1   Fernando Alonso   9.1     25
# 5      Sergio Perez  18.4     28
# 10     Lance Stroll   7.7     12
# 15     Yuki Tsunoda   4.7     16
# 21         Red Bull  27.6     97
# 22     Aston Martin   7.0     42
#
# Turbo driver: Max Verstappen
# Price: 101.80000000000001
# Points (no boost): 284
# Points with turbo driver: 348
# -----------------------------------------
# Race: Monaco
# Budget: 102.0 mln
# Squad
#                name price points
# 0    Max Verstappen  27.4     35
# 1   Fernando Alonso   9.2     27
# 3       Zhou Guanyu   4.7     11
# 6      Esteban Ocon   9.2     32
# 13  Valtteri Bottas   7.5     10
# 21         Red Bull  27.7     63
# 24           Alpine   9.9     42
#
# Turbo driver: Max Verstappen
# Price: 95.60000000000001
# Points (no boost): 220
# Points with turbo driver: 255
# -----------------------------------------
# Race: Spain
# Budget: 102.5 mln
# Squad
#               name price points
# 0   Max Verstappen  27.5     46
# 3      Zhou Guanyu   4.7     16
# 7     Pierre Gasly   8.1     14
# 10    Lance Stroll   7.6     16
# 11  George Russell  18.6     31
# 21        Red Bull  27.8     96
# 22    Aston Martin   7.0     40
#
# Turbo driver: Max Verstappen
# Price: 101.3
# Points (no boost): 259
# Points with turbo driver: 305
# -----------------------------------------
# Race: Canada
# Budget: 102.7 mln
# Squad
#                name price points
# 0    Max Verstappen  27.6     35
# 1   Fernando Alonso   9.4     27
# 5      Sergio Perez  18.4     28
# 12  Alexander Albon   4.9     22
# 15     Yuki Tsunoda   4.6      8
# 21         Red Bull  27.9     86
# 22     Aston Martin   7.0     41
#
# Turbo driver: Max Verstappen
# Price: 99.79999999999998
# Points (no boost): 247
# Points with turbo driver: 282
# -----------------------------------------
# Race: Austria
# Budget: 105.7 mln
# Squad
#               name price points
# 0   Max Verstappen  27.8     56
# 5     Sergio Perez  18.7     51
# 10    Lance Stroll   8.1     25
# 14  Logan Sargeant   3.5     19
# 18    Lando Norris  10.9     29
# 21        Red Bull  28.1    112
# 22    Aston Martin   8.0     63
#
# Turbo driver: Max Verstappen
# Price: 105.1
# Points (no boost): 355
# Points with turbo driver: 411
# -----------------------------------------
# Race: United Kingdom
# Budget: 107.60000000000001 mln
# Squad
#               name price points
# 0   Max Verstappen  27.9     46
# 5     Sergio Perez  19.0     26
# 14  Logan Sargeant   4.0      6
# 18    Lando Norris  11.4     38
# 19   Oscar Piastri   7.0     20
# 21        Red Bull  28.2     77
# 29         McLaren   9.8     68
#
# Turbo driver: Max Verstappen
# Price: 107.3
# Points (no boost): 281
# Points with turbo driver: 327
# -----------------------------------------
# Race: Hungary
# Budget: 111.10000000000001 mln
# Squad
#                name price points
# 0    Max Verstappen  28.1     46
# 5      Sergio Perez  19.3     39
# 12  Alexander Albon   6.9      8
# 14   Logan Sargeant   4.5      2
# 18     Lando Norris  12.9     29
# 21         Red Bull  28.4     95
# 29          McLaren  10.8     62
#
# Turbo driver: Max Verstappen
# Price: 110.89999999999999
# Points (no boost): 281
# Points with turbo driver: 327
# -----------------------------------------
# Race: Belgium
# Budget: 113.80000000000001 mln
# Squad
#                name price points
# 0    Max Verstappen  28.3     68
# 3       Zhou Guanyu   5.2     18
# 6      Esteban Ocon   9.7     23
# 7      Pierre Gasly   8.5     17
# 12  Alexander Albon   7.4     19
# 21         Red Bull  28.6     80
# 25         Mercedes  25.4     70
#
# Turbo driver: Max Verstappen
# Price: 113.1
# Points (no boost): 295
# Points with turbo driver: 363
# -----------------------------------------
# Race: Netherlands
# Budget: 116.50000000000001 mln
# Squad
#                name price points
# 0    Max Verstappen  28.5     46
# 1   Fernando Alonso  11.9     62
# 6      Esteban Ocon  10.7     26
# 7      Pierre Gasly   9.0     39
# 8      Carlos Sainz  17.3     31
# 21         Red Bull  28.7    101
# 22     Aston Martin  10.0     67
#
# Turbo driver: Fernando Alonso
# Price: 116.1
# Points (no boost): 372
# Points with turbo driver: 434
# -----------------------------------------
# Race: Monza
# Budget: 119.90000000000002 mln
# Squad
#                name price points
# 5      Sergio Perez  20.4     30
# 8      Carlos Sainz  17.6     38
# 12  Alexander Albon   8.4     12
# 13  Valtteri Bottas   8.4      8
# 19    Oscar Piastri   9.5     15
# 21         Red Bull  28.8     81
# 23          Ferrari  23.2     67
#
# Turbo driver: Carlos Sainz
# Price: 116.3
# Points (no boost): 251
# Points with turbo driver: 289
# -----------------------------------------
# Race: Singapore
# Budget: 122.70000000000002 mln
# Squad
#               name price points
# 7     Pierre Gasly    10     21
# 8     Carlos Sainz  18.6     45
# 9   Lewis Hamilton  25.3     39
# 18    Lando Norris  15.4     30
# 19   Oscar Piastri    10     24
# 23         Ferrari  23.5     70
# 29         McLaren  13.3     64
#
# Turbo driver: Carlos Sainz
# Price: 116.10000000000001
# Points (no boost): 293
# Points with turbo driver: 338
# -----------------------------------------
# Race: Japan
# Budget: 126.20000000000002 mln
# Squad
#                name price points
# 0    Max Verstappen  28.9     47
# 2   Charles Leclerc  22.7     22
# 4   Nico Hulkenberg   4.8     10
# 18     Lando Norris  15.7     31
# 19    Oscar Piastri  11.0     35
# 23          Ferrari  23.8     65
# 29          McLaren  14.3     66
#
# Turbo driver: Max Verstappen
# Price: 121.19999999999999
# Points (no boost): 276
# Points with turbo driver: 323
# -----------------------------------------
# Race: Qatar
# Budget: 129.70000000000002 mln
# Squad
#               name price points
# 0   Max Verstappen  29.1     62
# 3      Zhou Guanyu   6.7     19
# 11  George Russell  19.6     37
# 18    Lando Norris  16.7     41
# 19   Oscar Piastri  12.5     56
# 21        Red Bull  29.2     64
# 29         McLaren  15.3    110
#
# Turbo driver: Max Verstappen
# Price: 129.10000000000002
# Points (no boost): 389
# Points with turbo driver: 451
# -----------------------------------------
# Race: Austin
# Budget: 132.50000000000003 mln
# Squad
#               name price points
# 0   Max Verstappen  29.3     53
# 5     Sergio Perez  20.1     32
# 8     Carlos Sainz  19.4     32
# 15    Yuki Tsunoda   5.9     30
# 18    Lando Norris  17.0     46
# 21        Red Bull  29.3     95
# 30      AlphaTauri   6.7     34
#
# Turbo driver: Max Verstappen
# Price: 127.70000000000002
# Points (no boost): 322
# Points with turbo driver: 375
# -----------------------------------------
# Race: Mexico
# Budget: 135.30000000000004 mln
# Squad
#                 name price points
# 0     Max Verstappen  29.5     42
# 9     Lewis Hamilton  25.0     41
# 15      Yuki Tsunoda   6.9     20
# 18      Lando Norris  18.0     48
# 20  Daniel Ricciardo   4.5     12
# 23           Ferrari  24.3     63
# 25          Mercedes  25.9     69
#
# Turbo driver: Lando Norris
# Price: 134.1
# Points (no boost): 295
# Points with turbo driver: 343
# -----------------------------------------
# Race: Brazil
# Budget: 138.20000000000005 mln
# Squad
#                name price points
# 0    Max Verstappen  29.7     45
# 1   Fernando Alonso  14.7     39
# 5      Sergio Perez  20.2     37
# 10     Lance Stroll  12.0     28
# 18     Lando Norris  19.0     57
# 21         Red Bull  29.4    105
# 22     Aston Martin  11.9     77
#
# Turbo driver: Lando Norris
# Price: 136.9
# Points (no boost): 388
# Points with turbo driver: 445
# -----------------------------------------
# Race: Las Vegas
# Budget: 141.70000000000005 mln
# Squad
#                name price points
# 2   Charles Leclerc  23.2     41
# 5      Sergio Perez  20.5     35
# 6      Esteban Ocon  12.5     40
# 10     Lance Stroll  13.0     39
# 19    Oscar Piastri  14.4     39
# 21         Red Bull  29.6     84
# 23          Ferrari  24.7     78
#
# Turbo driver: Charles Leclerc
# Price: 137.9
# Points (no boost): 356
# Points with turbo driver: 397
# -----------------------------------------
# Race: Abu Dhabi
# Budget: 145.30000000000004 mln
# Squad
#               name price points
# 0   Max Verstappen  30.0     47
# 5     Sergio Perez  20.8     30
# 11  George Russell  20.2     32
# 15    Yuki Tsunoda   9.4     21
# 19   Oscar Piastri  15.4     19
# 21        Red Bull  29.7     87
# 29         McLaren  17.0     59
#
# Turbo driver: Max Verstappen
# Price: 142.5
# Points (no boost): 295
# Points with turbo driver: 342
# -----------------------------------------
# Season points: 7706
